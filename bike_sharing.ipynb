# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv("/Users/fesavaskurt/Python&ML/Kodlarım/Python/datasets/ML Datasets/biketest.csv")
df_train = pd.read_csv("/Users/fesavaskurt/Python&ML/Kodlarım/Python/datasets/ML Datasets/biketrain.csv")

# %%
df_train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df_train.shape
# Out:
# (10886, 12)

# %%
df_train = df_train.drop(columns=["casual", "registered"])

# %%
df_train["datetime"].unique
# Out:
# <bound method Series.unique of 0        2011-01-01 00:00:00
# 1        2011-01-01 01:00:00
# 2        2011-01-01 02:00:00
# 3        2011-01-01 03:00:00
# 4        2011-01-01 04:00:00
#                 ...
# 10881    2012-12-19 19:00:00
# 10882    2012-12-19 20:00:00
# 10883    2012-12-19 21:00:00
# 10884    2012-12-19 22:00:00
# 10885    2012-12-19 23:00:00
# Name: datetime, Length: 10886, dtype: object>

# %%
df_train["datetime"] = pd.to_datetime(df_train["datetime"])

# %%
df_train["datetime"] = pd.to_datetime(df_train["datetime"])

# %%
df_train["hour"] = df_train["datetime"].dt.hour
df_train["weekday"] = df_train["datetime"].dt.weekday
df_train["month"] = df_train["datetime"].dt.month
df_train["year"] = df_train["datetime"].dt.year

# %%
df_train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count  hour  weekday  month  year
# 0        81        0.0     16     0        5      1  2011
# 1        80        0.0     40     1        5      1  2011
# 2        80        0.0     32     2        5      1  2011
# 3        75        0.0     13     3        5      1  2011
# 4        75        0.0      1     4        5      1  2011

# %%
season_dummies = pd.get_dummies(df_train['season'], prefix='season', drop_first=True)

# %%
season_dummies
# Out:
#        season_2  season_3  season_4
# 0         False     False     False
# 1         False     False     False
# 2         False     False     False
# 3         False     False     False
# 4         False     False     False
# ...         ...       ...       ...
# 10881     False     False      True
# 10882     False     False      True
# 10883     False     False      True
# 10884     False     False      True
# 10885     False     False      True
#
# [10886 rows x 3 columns]

# %%
df_train = pd.concat([df_train, season_dummies], axis=1)

# %%
df_train
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  count  hour  weekday  month  year  \
# ...
