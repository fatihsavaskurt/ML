# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/Users/fesavaskurt/Python&ML/Kodlarım/Python/datasets/ML Datasets/10-diamonds.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# #### EDA

# %%
sns.boxplot(x = df["price"])
# Out:
# <Axes: xlabel='price'>

# %%
sns.kdeplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.lineplot(x = df["carat"], y = df["price"])
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
cut_map = {
    "Fair": 0,
    "Good": 1,
    "Very Good": 2,
    "Premium": 3,
    "Ideal": 4
}

# %%
df["color"].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
color_map = {
    "J": 0,
    "I": 1,
    "H": 2,
    "G": 3,
    "F": 4,
    "E": 5,
    "D": 6
}

# %%
df["clarity"].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
clarity_map = {
"I1" : 0,
"SI2" : 1,
"SI1" : 2,
"VS2" : 3,
"VS1" : 4,
"VVS2" : 5,
"VVS1" : 6,
"IF" : 7
}

# %%
df["clarity_map"] = df["clarity"].map(clarity_map)

# %%
df["color_map"] = df["color"].map(color_map)

# %%
df["cut_map"] = df["cut"].map(cut_map)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    color_map  cut_map  clarity_map
# 0          5        4            1
# 1          5        3            2
# 2          5        1            4
# 3          1        3            3
# 4          0        1            1

# %%
df.isnull().sum()
# Out:
# carat          0
# cut            0
# color          0
# clarity        0
# depth          0
# table          0
# price          0
# x              0
# y              0
# z              0
# color_map      0
# cut_map        0
# clarity_map    0
# dtype: int64

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    color_map  cut_map  clarity_map
# 0          5        4            1
# 1          5        3            2
# 2          5        1            4
# 3          1        3            3
# 4          0        1            1

# %%
df = df.drop(columns=["cut", "color", "clarity"])

# %%
df.head()
# Out:
#    carat  depth  table  price     x     y     z  color_map  cut_map  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43          5        4
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31          5        3
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31          5        1
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63          1        3
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75          0        1
#
#    clarity_map
# 0            1
# 1            2
# 2            4
# 3            3
# 4            1

# %%
X = df.drop(columns= ["price"])
y = df["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state= 42, test_size = 0.25
)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

# %%
svr = SVR()

# %%
svr.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
score = r2_score(y_test, y_pred)

print("mae: ", mae)
print("mse: ", mse)
print("score: ", score)
# Out:
# mae:  1284.5564540031467
# mse:  7460459.608233529
# score:  0.5251046500600618

# %%
df["price"].mean()
# Out:
# np.float64(3932.799721913237)

# %%
c_values = [100, 10, 1.0, 0.1, 0.01]
kernel = ["rbf", "linear", "poly"]
gamma = ["scale", "auto"]
epsilon = [5, 50, 100, 1000, 2000]

# %%
params = {
    "C": c_values,
    "kernel": kernel,
    "gamma": gamma,
    "epsilon": epsilon,
}

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
grid = GridSearchCV(estimator= SVR(), param_grid= params, cv=3)

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVR(),
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'epsilon': [5, 50, 100, 1000, 2000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly']})

# %%
y_pred = grid.predict(X_test_scaled)

# %%
grid.best_score_
# Out:
# np.float64(0.9587222759988611)

# %%
grid.best_params_
# Out:
# {'C': 100, 'epsilon': 100, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
grid.param_grid
# Out:
# {'C': [100, 10, 1.0, 0.1, 0.01],
#  'kernel': ['rbf', 'linear', 'poly'],
#  'gamma': ['scale', 'auto'],
#  'epsilon': [5, 50, 100, 1000, 2000]}

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
score = r2_score(y_test, y_pred)

print("mae: ", mae)
print("mse: ", mse)
print("score: ", score)
# Out:
# mae:  356.92012599619625
# mse:  521488.4006600793
# score:  0.9668046702849551
